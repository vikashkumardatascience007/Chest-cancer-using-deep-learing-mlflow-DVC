# %%
from box import ConfigBox
from ensure import ensure_annotations

# %%
d={'key1':'val1','key2':'val2'}

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
d['key1']
# Out:
# 'val1'

# %%
x=ConfigBox(d)

# %%
x.key1
# Out:
# 'val1'

# %%
def getSum(x:int,y:int):
    return x+y

# %%
getSum(x=4,y=3)
# Out:
# 7

# %%
getSum(x=4,y='3')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 getSum(x=4,y='3')
#
# Cell In[23], line 2, in getSum(x, y)
#       1 def getSum(x:int,y:int):
# ----> 2     return x+y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
@ensure_annotations
def getSum(x:int,y:int):
    return x+y

# %%
getSum(x=4,y='3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 getSum(x=4,y='3')
#
# File c:\Users\vikash.vk.kumar\AppData\Local\anaconda3\envs\cancer\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function getSum at 0x00000170C28631F0> does not match annotation type <class 'int'>
